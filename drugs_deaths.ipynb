# %%
import pandas as pd
import numpy as np

# %%
drug_deaths = pd.read_csv(r'C:\Users\lenovo\Downloads\Accidental_Drug_Related_Deaths_2012-2024.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
drug_deaths.head()
# Out:
#          Date      Date Type   Age   Sex   Race  \
# 0  01/02/2023  Date of death  65.0  Male  White
# 1  01/18/2023  Date of death  42.0  Male  White
# 2  01/26/2022  Date of death  34.0  Male  White
# 3  02/04/2023  Date of death  34.0  Male  White
# 4  02/18/2022  Date of death  43.0  Male  White
#
#                          Ethnicity Residence City Residence County  \
# 0  No, not Spanish/Hispanic/Latino     BRIDGEPORT        FAIRFIELD
# 1  No, not Spanish/Hispanic/Latino      WATERBURY        NEW HAVEN
# 2                              NaN     BROOKFIELD        FAIRFIELD
# 3                              NaN            NaN              NaN
# 4                              NaN        NORWICH       NEW LONDON
#
#   Residence State Injury City Injury County Injury State  \
# 0              CT  BRIDGEPORT     FAIRFIELD          NaN
# 1              CT  FARMINGTON      HARTFORD           CT
# 2              CT  BROOKFIELD     FAIRFIELD           CT
# 3             NaN   NEW HAVEN     NEW HAVEN           CT
# 4              CT     NORWICH    NEW LONDON           CT
#
#              Injury Place     Description of Injury Death City Death County  \
# 0                   Other             Substance use        NaN          NaN
# 1                    Home  Ethanol and Fentanyl Use        NaN          NaN
# 2                    Home           Substance Abuse        NaN          NaN
# 3                   Other             Substance Use        NaN          NaN
# 4  Public Recreation Area                  Drug Use        NaN          NaN
#
#   Death State         Location Location if Other  \
# 0         NaN              NaN               NaN
# 1         NaN              NaN               NaN
# 2         NaN  Decedent’s Home               NaN
# 3         NaN              NaN               NaN
# 4         NaN  Other (Specify)      Mohegan Park
#
#                                       Cause of Death Manner of Death  \
# 0  Acute Intoxication by the Combined Effects of ...        Accident
# 1  Combined Effects of Fentanyl and Ethanol Toxicity        Accident
# 2  Acute Intoxication due to the Combined Effects...        Accident
# 3  Acute Fentanyl Intoxication with Recent Cocain...        Accident
# 4            Acute Cocaine and Fentanyl Intoxication        Accident
#
#   Other Significant Conditions  Heroin Heroin death certificate (DC) Cocaine  \
# 0                           NaN    NaN                           NaN       Y
# 1                           NaN    NaN                           NaN     NaN
# 2                           NaN      Y                           NaN     NaN
# 3                           NaN    NaN                           NaN       Y
# 4                           NaN    NaN                           NaN       Y
#
#   Fentanyl Fentanyl Analogue Oxycodone Oxymorphone Ethanol Hydrocodone  \
# 0        Y               NaN       NaN         NaN     NaN         NaN
# 1        Y               NaN       NaN         NaN       Y         NaN
# 2        Y               NaN       NaN         NaN     NaN         NaN
# 3        Y               NaN       NaN         NaN     NaN         NaN
# 4        Y               NaN       NaN         NaN     NaN         NaN
#
#   Benzodiazepine Methadone Meth/Amphetamine Amphet Tramad Hydromorphone  \
# 0            NaN       NaN              NaN    NaN    NaN           NaN
# 1            NaN       NaN              NaN    NaN    NaN           NaN
# 2              Y       NaN              NaN    NaN    NaN           NaN
# 3            NaN       NaN              NaN    NaN    NaN           NaN
# 4            NaN       NaN              NaN    NaN    NaN           NaN
#
#   Morphine (Not Heroin) Xylazine Gabapentin Opiate NOS Heroin/Morph/Codeine  \
# 0                   NaN      NaN        NaN        NaN                  NaN
# 1                   NaN      NaN        NaN        NaN                  NaN
# 2                   NaN        Y        NaN        NaN                    Y
# 3                   NaN      NaN        NaN        NaN                  NaN
# 4                   NaN      NaN        NaN        NaN                  NaN
#
#   Other Opioid Any Opioid Other  \
# 0          NaN          Y   NaN
# 1          NaN          Y   NaN
# 2          NaN          Y   NaN
# 3          NaN          Y   NaN
# 4          NaN          Y   NaN
#
#                                     ResidenceCityGeo  \
# 0            BRIDGEPORT, CT\n(41.179195, -73.189476)
# 1           WATERBURY, CT\n(41.5542609, -73.0430692)
# 2  BROOKFIELD, CT\n(41.46736000000004, -73.398259...
# 3                   CT\n(41.57350273, -72.738305908)
# 4  NORWICH, CT\n(41.526760000000024, -72.07567999...
#
#                                        InjuryCityGeo  \
# 0            BRIDGEPORT, CT\n(41.179195, -73.189476)
# 1           FARMINGTON, CT\n(41.726536, -72.8250564)
# 2  BROOKFIELD, CT\n(41.46736000000004, -73.398259...
# 3           NEW HAVEN, CT\n(41.3082517, -72.9241605)
# 4  NORWICH, CT\n(41.526760000000024, -72.07567999...
#
#                                   DeathCityGeo
# 0             CT\n(41.57350273, -72.738305908)
# 1             CT\n(41.57350273, -72.738305908)
# 2  CT\n(41.57350273000003, -72.73830590799997)
# 3             CT\n(41.57350273, -72.738305908)
# 4  CT\n(41.57350273000003, -72.73830590799997)

# %% [markdown]
# ### Data Cleansing

# %% [markdown]
# #### capitalizing caps rows

# %%
# 1. converting nan values to blank as nan values can't be capitalised ->  fillna('')
# 2. creating a lambda function that capitalizes each row in specified columns ->  lambda x: x.capitalize()

drug_deaths[['Residence City', 'Residence County', 'Injury City', 'Injury County']] = drug_deaths[['Residence City', 'Residence County', 'Injury City', 'Injury County']].fillna('').map(lambda x: x.capitalize())

# %% [markdown]
# #### recreating ethnicity column

# %%
# ethnicity column values are inconsistent, overlapping, and confusing
drug_deaths['Ethnicity'].value_counts()
# Out:
# Ethnicity
# No, not Spanish/Hispanic/Latino                 1409
# Hispanic                                         972
# Yes, other Spanish/Hispanic/Latino               307
# Spanish/Hispanic/Latino                          267
# Other Spanish/Hispanic/Latino                    254
# Yes, Puerto Rican                                 85
# Not Spanish/Hispanic/Latino                       56
# Yes, Other Spanish/Hispanic/Latino (Specify)      26
# Unknown                                           24
# Puerto Rican                                      19
# Yes, Mexican, Mexican American, Chicano            8
# Mexican, Mexican American, Chicano                 4
# Cuban                                              2
# Yes, Cuban                                         1
# n                                                  1
# Name: count, dtype: int64

# %%
# creating a lambda function to make the column values significantly more readible

ethnicity_lambda = lambda x: (
    'Non-Hispanic/Latino' if (
        'no, not' in str(x).lower() or 
        'not spanish/hispanic/latino' in str(x).lower()
    ) 
    else 'Hispanic/Latino' if (
        'yes,' in str(x).lower() or 
        'hispanic' in str(x).lower() or 
        'latino' in str(x).lower() or 
        'puerto rican' in str(x).lower() or 
        'mexican' in str(x).lower() or 
        'chicano' in str(x).lower() or 
        'cuban' in str(x).lower()
    ) 
    else 'Unknown/Missing'
)

drug_deaths['Ethnicity_New'] = drug_deaths['Ethnicity'].apply(ethnicity_lambda)

# %%
# deleting the original ethnicity column

drug_deaths.drop(columns=('Ethnicity'), inplace=True)

# %% [markdown]
# #### getting rid of some columns

# %%
# the specified columns don't hold usable data but slow down the fetching

drug_deaths.drop(columns=(['ResidenceCityGeo', 'InjuryCityGeo', 'DeathCityGeo']), inplace=True)

# %% [markdown]
# #### checking for duplicates

# %%
# the table doesn't have any duplicates

drug_deaths[drug_deaths.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Date, Date Type, Age, Sex, Race, Residence City, Residence County, Residence State, Injury City, Injury County, Injury State, Injury Place, Description of Injury, Death City, Death County, Death State, Location, Location if Other, Cause of Death, Manner of Death, Other Significant Conditions , Heroin, Heroin death certificate (DC), Cocaine, Fentanyl, Fentanyl Analogue, Oxycodone, Oxymorphone, Ethanol, Hydrocodone, Benzodiazepine, Methadone, Meth/Amphetamine, Amphet, Tramad, Hydromorphone, Morphine (Not Heroin), Xylazine, Gabapentin, Opiate NOS, Heroin/Morph/Codeine, Other Opioid, Any Opioid, Other, ResidenceCityGeo, InjuryCityGeo, DeathCityGeo, Ethnicity_New]
# Index: []

# %% [markdown]
# #### modifying categorical values in Race column

# %%
# for example, categorical values like 'Black' and 'Black or African American' can be combined

drug_deaths.value_counts('Race')
# Out:
# Race
# White                                                       10802
# Black or African American                                    1027
# Black                                                         809
# Unknown                                                        63
# Other                                                          52
# Other (Specify)                                                46
# Asian Indian                                                   31
# Asian, Other                                                   24
# Other Asian                                                    12
# American Indian or Alaska Native                                6
# Asian/Indian                                                    5
# Asian                                                           4
# Other (Specify) Puerto Rican                                    3
# white                                                           3
# Chinese                                                         2
# Korean                                                          1
# Native American, Other                                          1
# Hawaiian                                                        1
# Japanese                                                        1
# Black or African American / American Indian Lenni Lenape        1
# Other (Specify) Haitian                                         1
# Other (Specify) portugese, Cape Verdean                         1
# Other Asian (Specify)                                           1
# Name: count, dtype: int64

# %%
drug_deaths['Race'] = drug_deaths['Race'].replace(
    {
    'Black' : 'Black or African American',
    'Other' : 'Other (Specify)',
    'Other (Specify) portuguese, Cape Verdean' : 'Other',
    'Other (Specify)' : 'Other',
    'Other (Specify) Puerto Rican' : 'Puerto Rican',
    'white' : 'White',
    'Native American, Other' : 'Other',
    'Black or African American / American Indian Lenni Lenape' : 'Other',
    'Other (Specify) Haitian' : 'Haitian',
    'Hawaiian' : 'Other',
    'Other Asian (Specify)' : 'Asian',
    'Asian Indian' : 'Asian',
    'Asian, Other' : 'Other',
    'Other, Asian' : 'Other',
    'Asian/Indian' : 'Other',
    'Unknown' : 'Other',
    'Other (Specify) portugese, Cape Verdean' : 'Other',
    'Other (Specify)' : 'Other',
    'Other Asian' : 'Asian',
    'Chinese' : 'Asian', 
    'Japanese' : 'Asian',
    'Korean' : 'Asian'
    }
)

# %%
drug_deaths.value_counts('Race')
# Out:
# Race
# White                               10805
# Black or African American            1836
# Other                                 142
# Asian                                  52
# Other (Specify)                        52
# American Indian or Alaska Native        6
# Puerto Rican                            3
# Haitian                                 1
# Name: count, dtype: int64

# %% [markdown]
# ### EDA

# %% [markdown]
# #### how many deaths occured each year?

# %%
# 1. converting 'date' column data type to datetime
# 2. extracting the year from it
# 3. grouping by year
# 4. checking how many deaths occured and sorting in descending order

drug_deaths.groupby(pd.to_datetime(drug_deaths['Date'], format='%m/%d/%Y').dt.year).size().sort_values(ascending=False)
# Out:
# Date
# 2021    1524
# 2022    1452
# 2020    1374
# 2023    1327
# 2019    1200
# 2017    1038
# 2018    1017
# 2024     982
# 2016     917
# 2015     729
# 2014     558
# 2013     490
# 2012     355
# dtype: int64

# %% [markdown]
# #### of those who died, how many were males / females?

# %%
drug_deaths.groupby('Sex').size()
# Out:
# Sex
# Female     3380
# Male       9571
# Unknown       2
# X             1
# dtype: int64

# %%
drug_deaths['Sex'].value_counts()
# Out:
# Sex
# Male       9571
# Female     3380
# Unknown       2
# X             1
# Name: count, dtype: int64

# %% [markdown]
# #### of those who died, what is the average age for males / females?

# %%
# not outputting 'Unknown', 'X' to not to skew the results

drug_deaths[~drug_deaths['Sex'].isin(['Unknown', 'X'])].groupby('Sex')['Age'].mean().round()
# Out:
# Sex
# Female    45.0
# Male      44.0
# Name: Age, dtype: float64

# %% [markdown]
# #### how many males of black or african american race below the age of 30 died in 2018?

# %%
drug_deaths[
    (drug_deaths['Sex'] == 'Male') & 
    (drug_deaths['Race'] == 'Black or African American') & 
    (drug_deaths['Age'] < 30) & 
    ((pd.to_datetime(drug_deaths['Date'], format='%m/%d/%Y').dt.year) == 2018)
]
# Out:
#              Date      Date Type   Age   Sex                       Race  \
# 3045   11/28/2018  Date of death  26.0  Male  Black or African American
# 3245   09/15/2018  Date of death  22.0  Male  Black or African American
# 4060   03/12/2018  Date of death  23.0  Male  Black or African American
# 4350   04/20/2018  Date of death  27.0  Male  Black or African American
# 4918   08/05/2018  Date of death  28.0  Male  Black or African American
# 5989   06/15/2018  Date of death  27.0  Male  Black or African American
# 6283   06/16/2018  Date of death  26.0  Male  Black or African American
# 7455   11/02/2018  Date of death  25.0  Male  Black or African American
# 10391  05/21/2018  Date of death  24.0  Male  Black or African American
# 10662  06/29/2018  Date of death  29.0  Male  Black or African American
#
#       Residence City Residence County Residence State Injury City  \
# 3045         Enfield         Hartford              CT     Enfield
# 3245      Uncasville       New london              CT  Uncasville
# 4060          Hamden        New haven              CT   New haven
# 4350      West haven        New haven              CT  West haven
# 4918        Hartford         Hartford              CT    Hartford
# 5989         Windsor         Hartford              CT    Hartford
# 6283       New haven        New haven              CT  West haven
# 7455         Windsor         Hartford              CT
# 10391         Groton       New london              CT      Groton
# 10662        Tamarac          Broward              FL    Hartford
#
#       Injury County Injury State            Injury Place  \
# 3045       Hartford          NaN               Residence
# 3245     New london          NaN               Residence
# 4060      New haven          NaN  Store or Shopping Area
# 4350      New haven          NaN               Residence
# 4918       Hartford          NaN               Residence
# 5989       Hartford          NaN              In Vehicle
# 6283      New haven          NaN               Residence
# 7455                         NaN                 Unknown
# 10391    New london          NaN               Residence
# 10662      Hartford          NaN         Apartment House
#
#       Description of Injury  Death City Death County Death State   Location  \
# 3045        Substance Abuse     ENFIELD     HARTFORD          CT  Residence
# 3245         Ingested drugs  UNCASVILLE   NEW LONDON          CT  Residence
# 4060        Substance Abuse   NEW HAVEN    NEW HAVEN          CT   Hospital
# 4350        Substance Abuse   NEW HAVEN    NEW HAVEN          CT   Hospital
# 4918             Drug abuse    HARTFORD     HARTFORD          CT  Residence
# 5989        Substance Abuse    HARTFORD     HARTFORD          CT   Hospital
# 6283        Substance abuse  WEST HAVEN    NEW HAVEN          CT      Other
# 7455        Substance Abuse    HARTFORD     HARTFORD          CT   Hospital
# 10391       Substance abuse     NORWICH   NEW LONDON          CT   Hospital
# 10662       Substance abuse    HARTFORD     HARTFORD          CT      Other
#
#       Location if Other                                     Cause of Death  \
# 3045                NaN                        Acute Fentanyl Intoxication
# 3245                NaN          Acute Methadone and Diazepam Intoxication
# 4060                NaN  Acute Intoxication due to the Combined Effects...
# 4350                NaN  Acute Intoxication From the Combined Effects o...
# 4918                NaN  Multidrug Toxicity Including Cocaine, Fentanyl...
# 5989                NaN  Complications of Acute and Chronic Opiate/Opio...
# 6283                NaN  ACUTE COMBINED FENTANYL, ACETYL FENTANYL, OXYC...
# 7455                NaN  Acute Intoxication From the Combined Effects o...
# 10391               NaN                        Acute Fentanyl Intoxication
# 10662               NaN                            ACUTE FENTANYL TOXICITY
#
#       Manner of Death Other Significant Conditions  Heroin  \
# 3045         Accident                           NaN    NaN
# 3245         Accident                           NaN    NaN
# 4060         Accident                           NaN      Y
# 4350         Accident                           NaN    NaN
# 4918         Accident                           NaN      Y
# 5989         Accident                           NaN    NaN
# 6283         Accident                           NaN    NaN
# 7455         Accident                           NaN    NaN
# 10391        Accident                           NaN    NaN
# 10662        Accident                           NaN    NaN
#
#       Heroin death certificate (DC) Cocaine Fentanyl Fentanyl Analogue  \
# 3045                            NaN     NaN        Y               NaN
# 3245                            NaN     NaN      NaN               NaN
# 4060                            NaN     NaN        Y               NaN
# 4350                            NaN     NaN      NaN               NaN
# 4918                            NaN       Y        Y               NaN
# 5989                            NaN     NaN      NaN               NaN
# 6283                            NaN     NaN        Y                 Y
# 7455                            NaN     NaN        Y               NaN
# 10391                           NaN     NaN        Y               NaN
# 10662                           NaN     NaN        Y               NaN
#
#       Oxycodone Oxymorphone Ethanol Hydrocodone Benzodiazepine Methadone  \
# 3045        NaN         NaN     NaN         NaN            NaN       NaN
# 3245        NaN         NaN     NaN         NaN              Y         Y
# 4060        NaN         NaN     NaN         NaN            NaN       NaN
# 4350          Y           Y       Y         NaN              Y       NaN
# 4918        NaN         NaN     NaN         NaN            NaN       NaN
# 5989        NaN         NaN     NaN         NaN            NaN       NaN
# 6283          Y         NaN       Y         NaN            NaN       NaN
# 7455        NaN         NaN       Y         NaN            NaN       NaN
# 10391       NaN         NaN     NaN         NaN            NaN       NaN
# 10662       NaN         NaN     NaN         NaN            NaN       NaN
#
#       Meth/Amphetamine Amphet Tramad Hydromorphone Morphine (Not Heroin)  \
# 3045               NaN    NaN    NaN           NaN                   NaN
# 3245               NaN    NaN    NaN           NaN                   NaN
# 4060               NaN    NaN    NaN           NaN                   NaN
# 4350               NaN    NaN    NaN           NaN                   NaN
# 4918               NaN    NaN    NaN           NaN                   NaN
# 5989               NaN    NaN    NaN           NaN                   NaN
# 6283               NaN    NaN    NaN           NaN                   NaN
# 7455               NaN    NaN    NaN           NaN                   NaN
# 10391              NaN    NaN    NaN           NaN                   NaN
# 10662              NaN    NaN    NaN           NaN                   NaN
#
#       Xylazine Gabapentin Opiate NOS Heroin/Morph/Codeine Other Opioid  \
# 3045       NaN        NaN        NaN                  NaN          NaN
# 3245       NaN        NaN        NaN                  NaN          NaN
# 4060       NaN        NaN        NaN                    Y          NaN
# 4350       NaN        NaN        NaN                  NaN          NaN
# 4918       NaN        NaN        NaN                    Y          NaN
# 5989       NaN        NaN          Y                    Y          NaN
# 6283       NaN        NaN        NaN                  NaN          NaN
# 7455       NaN        NaN        NaN                  NaN          NaN
# 10391      NaN        NaN        NaN                  NaN          NaN
# 10662      NaN        NaN        NaN                  NaN          NaN
#
#       Any Opioid Other                         ResidenceCityGeo  \
# 3045           Y   NaN     ENFIELD, CT\n(41.976501, -72.591985)
# 3245           Y   NaN  UNCASVILLE, CT\n(41.434399, -72.110298)
# 4060           Y   NaN      HAMDEN, CT\n(41.382918, -72.907743)
# 4350           Y   NaN  WEST HAVEN, CT\n(41.272336, -72.949817)
# 4918           Y   NaN    HARTFORD, CT\n(41.765775, -72.673356)
# 5989           Y   NaN      WINDSOR, CT\n(41.852781, -72.64379)
# 6283           Y   NaN   NEW HAVEN, CT\n(41.308252, -72.924161)
# 7455           Y   NaN      WINDSOR, CT\n(41.852781, -72.64379)
# 10391          Y   NaN       GROTON, CT\n(41.343693, -72.07877)
# 10662          Y   NaN                                      NaN
#
#                                  InjuryCityGeo  \
# 3045      ENFIELD, CT\n(41.976501, -72.591985)
# 3245   UNCASVILLE, CT\n(41.434399, -72.110298)
# 4060    NEW HAVEN, CT\n(41.308252, -72.924161)
# 4350   WEST HAVEN, CT\n(41.272336, -72.949817)
# 4918     HARTFORD, CT\n(41.765775, -72.673356)
# 5989     HARTFORD, CT\n(41.765775, -72.673356)
# 6283   WEST HAVEN, CT\n(41.272336, -72.949817)
# 7455               CT\n(41.575155, -72.738288)
# 10391       GROTON, CT\n(41.343693, -72.07877)
# 10662    HARTFORD, CT\n(41.765775, -72.673356)
#
#                                   DeathCityGeo    Ethnicity_New
# 3045      Enfield, CT\n(41.976501, -72.591985)  Unknown/Missing
# 3245   Uncasville, CT\n(41.434399, -72.110298)  Unknown/Missing
# 4060    New Haven, CT\n(41.308252, -72.924161)  Unknown/Missing
# 4350    New Haven, CT\n(41.308252, -72.924161)  Unknown/Missing
# 4918     Hartford, CT\n(41.765775, -72.673356)  Unknown/Missing
# 5989     Hartford, CT\n(41.765775, -72.673356)  Hispanic/Latino
# 6283   West Haven, CT\n(41.272336, -72.949817)  Unknown/Missing
# 7455     Hartford, CT\n(41.765775, -72.673356)  Unknown/Missing
# 10391     Norwich, CT\n(41.524304, -72.075821)  Unknown/Missing
# 10662    Hartford, CT\n(41.765775, -72.673356)  Unknown/Missing

# %% [markdown]
# #### what are the top 5 causes of death?

# %%
drug_deaths.groupby('Cause of Death').size().sort_values(ascending=False).head(5)
# Out:
# Cause of Death
# Acute Fentanyl Intoxication    578
# Acute Cocaine Intoxication     164
# Multiple Drug Toxicity         131
# Heroin Intoxication            130
# Acute Heroin Intoxication      121
# dtype: int64

# %% [markdown]
# #### list of people who were intoxicated by more than 3 drugs

# %%
# 1. creating a 'num_drugs' columns
# 2. creating a lambda function that defines the number of times a row has 'Y' value
# 3. outputting people who were intoxicated by over 3 drugs
drug_deaths['num_drugs'] = drug_deaths.apply(lambda x: (x == 'Y').sum(), axis=1)

# %%
drug_deaths[drug_deaths['num_drugs'] > 3]
# Out:
#              Date      Date Type   Age     Sex                       Race  \
# 2      01/26/2022  Date of death  34.0    Male                      White
# 5      02/18/2022  Date of death  38.0    Male                      White
# 9      04/16/2022  Date of death  24.0    Male                      White
# 16     07/25/2023  Date of death  62.0  Female                      White
# 17     08/11/2023  Date of death  32.0    Male                      White
# ...           ...            ...   ...     ...                        ...
# 12953  03/10/2024  Date of death  49.0  Female  Black or African American
# 12956  05/28/2024  Date of death  41.0    Male  Black or African American
# 12958  09/01/2024  Date of death  48.0    Male  Black or African American
# 12959  03/14/2024  Date of death  53.0    Male                      White
# 12961  02/01/2024  Date of death  66.0    Male                      White
#
#       Residence City Residence County Residence State Injury City  \
# 2         Brookfield        Fairfield              CT  Brookfield
# 5          Waterbury        New haven              CT   Waterbury
# 9             Bozrah       New london              CT      Bozrah
# 16           Danbury        Fairfield              CT     Danbury
# 17          Brooklyn          Windham              CT    Brooklyn
# ...              ...              ...             ...         ...
# 12953      New haven        New haven              CT   New haven
# 12956        Bristol         Hartford              CT     Bristol
# 12958      Waterbury        New haven              CT   Waterbury
# 12959       Hartford         Hartford              CT    Hartford
# 12961       Dayville          Windham              CT    Dayville
#
#       Injury County Injury State Injury Place Description of Injury  \
# 2         Fairfield           CT         Home       Substance Abuse
# 5         New haven           CT         Home              Drug use
# 9        New london           CT         Home       Substance abuse
# 16        Fairfield           CT         Home      Substance abuse.
# 17          Windham           CT         Home         Substance Use
# ...             ...          ...          ...                   ...
# 12953     New haven           CT        Other         Substance Use
# 12956      Hartford           CT         Home         Substance Use
# 12958     New haven           CT         Home         Substance Use
# 12959      Hartford           CT         Home         substance use
# 12961       Windham           CT         Home              Drug Use
#
#       Death City Death County Death State                  Location  \
# 2            NaN          NaN         NaN           Decedent’s Home
# 5            NaN          NaN         NaN  Hospital - ER/Outpatient
# 9            NaN          NaN         NaN           Decedent’s Home
# 16           NaN          NaN         NaN                       NaN
# 17           NaN          NaN         NaN                       NaN
# ...          ...          ...         ...                       ...
# 12953        NaN          NaN         NaN                       NaN
# 12956        NaN          NaN         NaN                       NaN
# 12958        NaN          NaN         NaN                       NaN
# 12959        NaN          NaN         NaN                       NaN
# 12961        NaN          NaN         NaN                       NaN
#
#       Location if Other                                     Cause of Death  \
# 2                   NaN  Acute Intoxication due to the Combined Effects...
# 5                   NaN  Acute Intoxication Combined Effects of Ethanol...
# 9                   NaN  Acute Intoxication by the Combined Effects of ...
# 16                  NaN  Acute Intoxication the Combined Effects of fen...
# 17                  NaN  Acute Intoxication by the Combined Effects of ...
# ...                 ...                                                ...
# 12953               NaN  Acute Intoxication by the Combined Effects of ...
# 12956               NaN  Acute Intoxication by the Combined Effects of ...
# 12958               NaN  Acute Intoxication by the Combined Effects of ...
# 12959               NaN  Acute Intoxication due to the Combined Effects...
# 12961               NaN  Acute Intoxication due to the Combined Effects...
#
#       Manner of Death                Other Significant Conditions  Heroin  \
# 2            Accident                                          NaN      Y
# 5            Accident                                          NaN      Y
# 9            Accident                                          NaN    NaN
# 16           Accident                                          NaN      Y
# 17           Accident                                          NaN    NaN
# ...               ...                                          ...    ...
# 12953        Accident                                          NaN    NaN
# 12956        Accident                                          NaN    NaN
# 12958        Accident                                          NaN    NaN
# 12959        Accident  Influenza A Infection with Bronchopneumonia    NaN
# 12961        Accident                                          NaN    NaN
#
#       Heroin death certificate (DC) Cocaine Fentanyl Fentanyl Analogue  \
# 2                               NaN     NaN        Y               NaN
# 5                               NaN       Y      NaN               NaN
# 9                               NaN       Y        Y               NaN
# 16                              NaN     NaN        Y               NaN
# 17                              NaN       Y        Y               NaN
# ...                             ...     ...      ...               ...
# 12953                           NaN       Y        Y               NaN
# 12956                           NaN       Y        Y               NaN
# 12958                           NaN     NaN        Y               NaN
# 12959                           NaN     NaN        Y               NaN
# 12961                           NaN     NaN        Y               NaN
#
#       Oxycodone Oxymorphone Ethanol Hydrocodone Benzodiazepine Methadone  \
# 2           NaN         NaN     NaN         NaN              Y       NaN
# 5           NaN         NaN       Y         NaN            NaN       NaN
# 9           NaN         NaN       Y         NaN            NaN       NaN
# 16          NaN         NaN     NaN         NaN            NaN         Y
# 17          NaN         NaN       Y         NaN            NaN       NaN
# ...         ...         ...     ...         ...            ...       ...
# 12953       NaN         NaN       Y         NaN            NaN       NaN
# 12956         Y         NaN     NaN         NaN            NaN       NaN
# 12958         Y         NaN     NaN         NaN              Y       NaN
# 12959       NaN         NaN     NaN         NaN            NaN         Y
# 12961       NaN         NaN     NaN         NaN            NaN         Y
#
#       Meth/Amphetamine Amphet Tramad Hydromorphone Morphine (Not Heroin)  \
# 2                  NaN    NaN    NaN           NaN                   NaN
# 5                  NaN    NaN    NaN           NaN                   NaN
# 9                  NaN    NaN    NaN           NaN                   NaN
# 16                 NaN    NaN    NaN           NaN                   NaN
# 17                 NaN    NaN    NaN           NaN                   NaN
# ...                ...    ...    ...           ...                   ...
# 12953              NaN    NaN    NaN           NaN                   NaN
# 12956              NaN      Y    NaN           NaN                   NaN
# 12958              NaN    NaN    NaN           NaN                   NaN
# 12959              NaN    NaN    NaN           NaN                   NaN
# 12961              NaN    NaN    NaN           NaN                   NaN
#
#       Xylazine Gabapentin Opiate NOS Heroin/Morph/Codeine Other Opioid  \
# 2            Y        NaN        NaN                    Y          NaN
# 5          NaN        NaN        NaN                    Y          NaN
# 9          NaN        NaN        NaN                  NaN          NaN
# 16         NaN        NaN        NaN                    Y          NaN
# 17           Y        NaN        NaN                  NaN          NaN
# ...        ...        ...        ...                  ...          ...
# 12953      NaN        NaN        NaN                  NaN          NaN
# 12956      NaN        NaN        NaN                  NaN          NaN
# 12958        Y        NaN        NaN                  NaN          NaN
# 12959        Y        NaN        NaN                  NaN          NaN
# 12961        Y          Y        NaN                  NaN          NaN
#
#       Any Opioid Other                                   ResidenceCityGeo  \
# 2              Y   NaN  BROOKFIELD, CT\n(41.46736000000004, -73.398259...
# 5              Y   NaN  WATERBURY, CT\n(41.55490000000003, -73.0464699...
# 9              Y   NaN  BOZRAH, CT\n(41.56752000000006, -72.1506099999...
# 16             Y   NaN               DANBURY, CT\n(41.393666, -73.451539)
# 17             Y   NaN            BROOKLYN, CT\n(41.7882521, -71.9496283)
# ...          ...   ...                                                ...
# 12953          Y   NaN               NEW HAVEN, CT\n(41.30801, -72.92432)
# 12956          Y   NaN                 BRISTOL, CT\n(41.67574, -72.94661)
# 12958          Y   NaN                WATERBURY, CT\n(41.5549, -73.04647)
# 12959          Y   NaN                HARTFORD, CT\n(41.76381, -72.67397)
# 12961          Y   NaN                DAYVILLE, CT\n(41.84559, -71.88653)
#
#                                            InjuryCityGeo  \
# 2      BROOKFIELD, CT\n(41.46736000000004, -73.398259...
# 5      WATERBURY, CT\n(41.55490000000003, -73.0464699...
# 9      BOZRAH, CT\n(41.56752000000006, -72.1506099999...
# 16                  DANBURY, CT\n(41.393666, -73.451539)
# 17               BROOKLYN, CT\n(41.7882521, -71.9496283)
# ...                                                  ...
# 12953               NEW HAVEN, CT\n(41.30801, -72.92432)
# 12956                 BRISTOL, CT\n(41.67574, -72.94661)
# 12958                WATERBURY, CT\n(41.5549, -73.04647)
# 12959                HARTFORD, CT\n(41.76381, -72.67397)
# 12961                DAYVILLE, CT\n(41.84559, -71.88653)
#
#                                       DeathCityGeo        Ethnicity_New  \
# 2      CT\n(41.57350273000003, -72.73830590799997)      Unknown/Missing
# 5      CT\n(41.57350273000003, -72.73830590799997)      Unknown/Missing
# 9      CT\n(41.57350273000003, -72.73830590799997)      Unknown/Missing
# 16                CT\n(41.57350273, -72.738305908)      Unknown/Missing
# 17                CT\n(41.57350273, -72.738305908)      Unknown/Missing
# ...                                            ...                  ...
# 12953                    CT\n(41.76381, -72.67398)      Unknown/Missing
# 12956                    CT\n(41.76381, -72.67398)  Non-Hispanic/Latino
# 12958                    CT\n(41.76381, -72.67398)  Non-Hispanic/Latino
# 12959                    CT\n(41.76381, -72.67398)      Hispanic/Latino
# 12961                    CT\n(41.76381, -72.67398)  Non-Hispanic/Latino
#
#        num_drugs
# 2              6
# 5              5
# 9              4
# 16             5
# 17             5
# ...          ...
# 12953          4
# 12956          5
# 12958          5
# 12959          4
# 12961          5
#
# [5654 rows x 49 columns]

# %% [markdown]
# #### for top 5 counties by death count, what is the average age for men / women that died there?

# %%
# 1. outputting 5 counties with the highest death count and assigning it to top_counties_deaths

top_counties_deaths = drug_deaths.groupby('Death County').size().sort_values(ascending=False).head()

# %%
# 2. grouping only by 5 counties with the highest death count, then grouping by sex and outputting the average age
# 3. converting the series to dataframe (and renaming mean age column) to prepare it for an upcoming join

drug_deaths.groupby(['Death County', 'Sex'])['Age'].mean().round().loc[top_counties_deaths.index]
df_death_county_grouped = drug_deaths.groupby(['Death County', 'Sex'])['Age'].mean().round().loc[top_counties_deaths.index].rename('Mean Age').to_frame()

# %%
# 4. the purpose of the join is to output the number of deaths occurred in listed counties
#    converting top_counties_deaths to dataframe too and joining two dataframes


df_final = df_death_county_grouped.join(top_counties_deaths.rename('Total Deaths').to_frame(), on='Death County')
df_final
# Out:
#                      Mean Age  Total Deaths
# Death County Sex
# HARTFORD     Female      43.0          2441
#              Male        44.0          2441
# NEW HAVEN    Female      44.0          2406
#              Male        44.0          2406
# FAIRFIELD    Female      44.0          1278
#              Male        43.0          1278
# NEW LONDON   Female      41.0           726
#              Male        42.0           726
# LITCHFIELD   Female      43.0           418
#              Male        41.0           418

# %%
# 5. finally, resetting index to fix column name misalignment

df_final.reset_index(inplace=True)
df_final
# Out:
#   Death County     Sex  Mean Age  Total Deaths
# 0     HARTFORD  Female      43.0          2441
# 1     HARTFORD    Male      44.0          2441
# 2    NEW HAVEN  Female      44.0          2406
# 3    NEW HAVEN    Male      44.0          2406
# 4    FAIRFIELD  Female      44.0          1278
# 5    FAIRFIELD    Male      43.0          1278
# 6   NEW LONDON  Female      41.0           726
# 7   NEW LONDON    Male      42.0           726
# 8   LITCHFIELD  Female      43.0           418
# 9   LITCHFIELD    Male      41.0           418

# %%
# but the following output is also possible:

drug_deaths.groupby(['Death County', 'Sex'])['Age'].mean().round().loc[top_counties_deaths.index]
# Out:
# Death County  Sex
# HARTFORD      Female    43.0
#               Male      44.0
# NEW HAVEN     Female    44.0
#               Male      44.0
# FAIRFIELD     Female    44.0
#               Male      43.0
# NEW LONDON    Female    41.0
#               Male      42.0
# LITCHFIELD    Female    43.0
#               Male      41.0
# Name: Age, dtype: float64
